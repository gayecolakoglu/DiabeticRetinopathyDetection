# %% [markdown]
# <a href="https://colab.research.google.com/github/gayecolakoglu/DiabeticRetinopathyDetection/blob/main/augmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import os
import cv2
import glob
import shutil
from PIL import Image
import tensorflow as tf
from keras.preprocessing import image

# %%
import pathlib
from google.colab import drive
drive.mount('/content/gdrive',force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
data_dir = "/content/gdrive/MyDrive/KaggleImageData/allDataCLAHE"
#data_dir = "/content/gdrive/MyDrive/KaggleImageData/UfukHocaVeri/CLAHE"
data_dir = pathlib.Path(data_dir)

# %%
image_count = len(list(data_dir.glob('0/*.jpeg')))
print("class 0:",image_count)
image_count = len(list(data_dir.glob('1/*.jpeg')))
print("class 1:",image_count)
image_count = len(list(data_dir.glob('2/*.jpeg')))
print("class 2:",image_count)
image_count = len(list(data_dir.glob('3/*.jpeg')))
print("class 3:",image_count)
image_count = len(list(data_dir.glob('4/*.jpeg')))
print("class 4:",image_count)
# Out:
# class 0: 6221
# class 1: 1084
# class 2: 1253
# class 3: 406
# class 4: 312

# %%
def augment_using_ops(path):
  import matplotlib.pyplot as plt
  for filename in os.listdir(path):
    try:
      print(filename)
      print(os.path.join(path,filename))
      img = cv2.imread(os.path.join(path,filename))
      img = tf.image.random_flip_left_right(img)
      img = tf.image.random_flip_up_down(img)
      img = tf.image.rot90(img)
      img = np.array(img)
      plt.imshow(img)
      cv2.imwrite(path+'augmented'+filename,img)

    except:
      continue

# %%
path = "/content/gdrive/MyDrive/KaggleImageData/allDataCLAHE/4/"
augment_using_ops(path)
# Out:
# 25378_right.jpeg.jpeg
# /content/gdrive/MyDrive/KaggleImageData/allDataCLAHE/4/25378_right.jpeg.jpeg
# 24019_right.jpeg.jpeg
# /content/gdrive/MyDrive/KaggleImageData/allDataCLAHE/4/24019_right.jpeg.jpeg
# 23648_right.jpeg.jpeg
# /content/gdrive/MyDrive/KaggleImageData/allDataCLAHE/4/23648_right.jpeg.jpeg
# 217_right.jpeg.jpeg
# /content/gdrive/MyDrive/KaggleImageData/allDataCLAHE/4/217_right.jpeg.jpeg
# 22271_left.jpeg.jpeg
# /content/gdrive/MyDrive/KaggleImageData/allDataCLAHE/4/22271_left.jpeg.jpeg
# 22379_right.jpeg.jpeg
# /content/gdrive/MyDrive/KaggleImageData/allDataCLAHE/4/22379_right.jpeg.jpeg
# 22379_left.jpeg.jpeg
# /content/gdrive/MyDrive/KaggleImageData/allDataCLAHE/4/22379_left.jpeg.jpeg
# 22271_right.jpeg.jpeg
# /content/gdrive/MyDrive/KaggleImageData/allDataCLAHE/4/22271_right.jpeg.jpeg
# 22160_right.jpeg.jpeg
# /content/gdrive/MyDrive/KaggleImageData/allDataCLAHE/4/22160_right.jpeg.jpeg
# 22520_left.jpeg.jpeg
# ...

# %%
path2 = "/content/gdrive/MyDrive/KaggleImageData/allDataCLAHE/3/"
augment_using_ops(path2)
# Out:
# 26888_right.jpeg.jpeg
# /content/gdrive/MyDrive/KaggleImageData/allDataCLAHE/3/26888_right.jpeg.jpeg
# 22778_left.jpeg.jpeg
# /content/gdrive/MyDrive/KaggleImageData/allDataCLAHE/3/22778_left.jpeg.jpeg
# 22769_left.jpeg.jpeg
# /content/gdrive/MyDrive/KaggleImageData/allDataCLAHE/3/22769_left.jpeg.jpeg
# 22778_right.jpeg.jpeg
# /content/gdrive/MyDrive/KaggleImageData/allDataCLAHE/3/22778_right.jpeg.jpeg
# 2275_left.jpeg.jpeg
# /content/gdrive/MyDrive/KaggleImageData/allDataCLAHE/3/2275_left.jpeg.jpeg
# 23485_left.jpeg.jpeg
# /content/gdrive/MyDrive/KaggleImageData/allDataCLAHE/3/23485_left.jpeg.jpeg
# 23244_right.jpeg.jpeg
# /content/gdrive/MyDrive/KaggleImageData/allDataCLAHE/3/23244_right.jpeg.jpeg
# 21177_left.jpeg.jpeg
# /content/gdrive/MyDrive/KaggleImageData/allDataCLAHE/3/21177_left.jpeg.jpeg
# 21033_left.jpeg.jpeg
# /content/gdrive/MyDrive/KaggleImageData/allDataCLAHE/3/21033_left.jpeg.jpeg
# 20858_left.jpeg.jpeg
# ...

# %%
path3 = "/content/gdrive/MyDrive/KaggleImageData/allDataCLAHE/1/"
augment_using_ops(path3)
# Out:
# 27850_left.jpeg.jpeg
# /content/gdrive/MyDrive/KaggleImageData/allDataCLAHE/1/27850_left.jpeg.jpeg
# 24990_right.jpeg.jpeg
# /content/gdrive/MyDrive/KaggleImageData/allDataCLAHE/1/24990_right.jpeg.jpeg
# 27077_right.jpeg.jpeg
# /content/gdrive/MyDrive/KaggleImageData/allDataCLAHE/1/27077_right.jpeg.jpeg
# 26649_left.jpeg.jpeg
# /content/gdrive/MyDrive/KaggleImageData/allDataCLAHE/1/26649_left.jpeg.jpeg
# 24033_right.jpeg.jpeg
# /content/gdrive/MyDrive/KaggleImageData/allDataCLAHE/1/24033_right.jpeg.jpeg
# 23786_left.jpeg.jpeg
# /content/gdrive/MyDrive/KaggleImageData/allDataCLAHE/1/23786_left.jpeg.jpeg
# 23541_left.jpeg.jpeg
# /content/gdrive/MyDrive/KaggleImageData/allDataCLAHE/1/23541_left.jpeg.jpeg
# 23548_left.jpeg.jpeg
# /content/gdrive/MyDrive/KaggleImageData/allDataCLAHE/1/23548_left.jpeg.jpeg
# 23534_right.jpeg.jpeg
# /content/gdrive/MyDrive/KaggleImageData/allDataCLAHE/1/23534_right.jpeg.jpeg
# 23538_right.jpeg.jpeg
# ...
